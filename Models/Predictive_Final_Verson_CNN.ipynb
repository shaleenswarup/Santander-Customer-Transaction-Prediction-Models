# %%
# Data manipulation and set-up
import numpy as np
import pandas as pd

# Visualisation
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1)

# Modelling (including set-up & evaluation)
from sklearn.model_selection import KFold, StratifiedKFold
import lightgbm as lgb
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import roc_auc_score

# Ignore warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings('ignore')

#for neural network
import lightgbm as lgb

from sklearn.metrics import roc_auc_score, log_loss
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold,KFold
from scipy.stats import norm, skew

from tqdm import tqdm_notebook as tqdm
from copy import copy
from multiprocessing import Pool

np.random.seed(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
# !unzip '/content/drive/MyDrive/santander-customer-transaction-prediction.zip'
# Out:
# Archive:  /content/drive/MyDrive/santander-customer-transaction-prediction.zip
#   inflating: sample_submission.csv
#   inflating: test.csv
#   inflating: train.csv

# %% [markdown]
# ## Importing Data

# %%
random_state = 42
np.random.seed(random_state)
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# ## Data Oversampling
# * We are increasing our number of samples to train on by increasing the percentage of samples where Target = 1. Only 10% of the features are Target = 1. We are oversampling Target = 1 by 3 times.

# %%
def oversampling(x,y,t=2):
    samples =  []
    for i in range(t):
        mask = y>0
        x1 = x[mask].copy()
        ids = np.arange(x1.shape[0])
        for c in range(x1.shape[1]):
            np.random.shuffle(ids)
            x1[:,c] = x1[ids][:,c]
        samples.append(x1)


    samples = np.vstack(samples)
    sample_targets = np.ones(samples.shape[0])
    x = np.vstack([x,samples])
    y = np.concatenate([y,sample_targets])
    return x,y

# %%
skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=random_state)
val_aucs = []

# %%
features = [col for col in train.columns if col not in ['target', 'ID_code']]
X_test = test[features].values

# %% [markdown]
# # Neural Network(CNN) - 4 layers

# %% [markdown]
# ### CNN Model parameters, Model, learning rate scheduler

# %%
import keras

n_splits = 7
num_preds = 1
epochs = 60
learning_rate_init = 0.02
batch_size = 4000
num_features = 200



def get_model_3():
    inp = keras.layers.Input((num_features*num_preds,))
    x = keras.layers.Reshape((num_features*num_preds,1))(inp)
    x = keras.layers.Conv1D(32,num_preds,strides=num_preds, activation='elu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv1D(24,1, activation='elu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv1D(16,1, activation='elu')(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Conv1D(4,1, activation='elu')(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.Reshape((num_features*4,1))(x)
    x = keras.layers.AveragePooling1D(2)(x)
    x = keras.layers.Flatten()(x)
    x = keras.layers.BatchNormalization()(x)
    out = keras.layers.Dense(1, activation='sigmoid')(x)
    return keras.Model(inputs=inp, outputs=out)


def lr_scheduler(epoch):
    if epoch <= epochs*0.8:
        return learning_rate_init
    else:
        return learning_rate_init * 0.1

predictions_nn1 = test[['ID_code']]

# %%
for fold, (trn_idx, val_idx) in enumerate(skf.split(train, train['target'])):
    X_train, y_train = train.iloc[trn_idx][features], train.iloc[trn_idx]['target']
    X_valid, y_valid = train.iloc[val_idx][features], train.iloc[val_idx]['target']
     
    p_valid,yp = 0,0

    X_t, y_t = oversampling(X_train.values, y_train.values)
    X_t = pd.DataFrame(X_t)
    X_t = X_t.add_prefix('var_')

    optimizer = keras.optimizers.Adam(lr = learning_rate_init, decay = 0.00001)
    model = get_model_3()
    callbacks = []
    callbacks.append(keras.callbacks.LearningRateScheduler(lr_scheduler))
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])
    model.fit(X_t, y_t, validation_data=(X_valid, y_valid), epochs=epochs, verbose=2, batch_size=batch_size, callbacks=callbacks)
    p_valid += model.predict(X_valid, batch_size=2000)[:,0]
    yp = model.predict(test[features])
    val_score = roc_auc_score(y_valid, p_valid)
    val_aucs.append(val_score)

    print(roc_auc_score(y_valid, p_valid))
  
    predictions_nn1['fold{}'.format(fold+1)] = yp
# Out:
# Epoch 1/60
# 41/41 - 73s - loss: 0.4247 - accuracy: 0.8063 - val_loss: 0.3574 - val_accuracy: 0.9012
# Epoch 2/60
# 41/41 - 75s - loss: 0.3667 - accuracy: 0.8406 - val_loss: 0.6236 - val_accuracy: 0.8996
# Epoch 3/60
# 41/41 - 74s - loss: 0.3613 - accuracy: 0.8429 - val_loss: 1.0190 - val_accuracy: 0.8995
# Epoch 4/60
# 41/41 - 75s - loss: 0.3566 - accuracy: 0.8458 - val_loss: 0.8598 - val_accuracy: 0.8995
# Epoch 5/60
# 41/41 - 74s - loss: 0.3591 - accuracy: 0.8449 - val_loss: 0.8315 - val_accuracy: 0.8995
# Epoch 6/60
# 41/41 - 71s - loss: 0.3535 - accuracy: 0.8474 - val_loss: 0.4749 - val_accuracy: 0.9001
# Epoch 7/60
# 41/41 - 73s - loss: 0.3541 - accuracy: 0.8465 - val_loss: 0.3927 - val_accuracy: 0.9024
# Epoch 8/60
# 41/41 - 81s - loss: 0.3558 - accuracy: 0.8469 - val_loss: 0.5499 - val_accuracy: 0.9000
# Epoch 9/60
# 41/41 - 82s - loss: 0.3525 - accuracy: 0.8481 - val_loss: 0.6774 - val_accuracy: 0.8996
# Epoch 10/60
# 41/41 - 90s - loss: 0.3511 - accuracy: 0.8484 - val_loss: 0.2559 - val_accuracy: 0.9134
# Epoch 11/60
# 41/41 - 88s - loss: 0.3538 - accuracy: 0.8472 - val_loss: 0.7547 - val_accuracy: 0.8995
# Epoch 12/60
# 41/41 - 87s - loss: 0.3532 - accuracy: 0.8482 - val_loss: 0.8808 - val_accuracy: 0.8995
# Epoch 13/60
# 41/41 - 84s - loss: 0.3506 - accuracy: 0.8495 - val_loss: 0.5928 - val_accuracy: 0.9001
# Epoch 14/60
# 41/41 - 83s - loss: 0.3503 - accuracy: 0.8495 - val_loss: 0.9840 - val_accuracy: 0.5064
# Epoch 15/60
# 41/41 - 84s - loss: 0.3529 - accuracy: 0.8478 - val_loss: 0.2781 - val_accuracy: 0.9088
# Epoch 16/60
# 41/41 - 85s - loss: 0.3563 - accuracy: 0.8462 - val_loss: 0.8983 - val_accuracy: 0.8995
# Epoch 17/60
# 41/41 - 85s - loss: 0.3528 - accuracy: 0.8476 - val_loss: 0.2676 - val_accuracy: 0.9158
# Epoch 18/60
# 41/41 - 84s - loss: 0.3524 - accuracy: 0.8483 - val_loss: 1.2859 - val_accuracy: 0.8995
# Epoch 19/60
# 41/41 - 84s - loss: 0.3498 - accuracy: 0.8494 - val_loss: 0.9844 - val_accuracy: 0.8995
# Epoch 20/60
# 41/41 - 79s - loss: 0.3514 - accuracy: 0.8483 - val_loss: 0.4718 - val_accuracy: 0.9030
# Epoch 21/60
# 41/41 - 77s - loss: 0.3512 - accuracy: 0.8489 - val_loss: 0.7367 - val_accuracy: 0.8998
# Epoch 22/60
# 41/41 - 76s - loss: 0.3495 - accuracy: 0.8496 - val_loss: 0.5906 - val_accuracy: 0.9003
# Epoch 23/60
# 41/41 - 79s - loss: 0.3499 - accuracy: 0.8499 - val_loss: 0.2268 - val_accuracy: 0.9192
# Epoch 24/60
# 41/41 - 76s - loss: 0.3509 - accuracy: 0.8487 - val_loss: 1.2204 - val_accuracy: 0.8995
# Epoch 25/60
# 41/41 - 76s - loss: 0.3527 - accuracy: 0.8480 - val_loss: 0.5331 - val_accuracy: 0.9003
# Epoch 26/60
# 41/41 - 75s - loss: 0.3503 - accuracy: 0.8496 - val_loss: 0.7308 - val_accuracy: 0.8997
# Epoch 27/60
# 41/41 - 74s - loss: 0.3500 - accuracy: 0.8499 - val_loss: 0.5721 - val_accuracy: 0.9001
# Epoch 28/60
# 41/41 - 76s - loss: 0.3502 - accuracy: 0.8493 - val_loss: 0.9779 - val_accuracy: 0.5444
# Epoch 29/60
# 41/41 - 75s - loss: 0.3500 - accuracy: 0.8497 - val_loss: 0.3421 - val_accuracy: 0.9062
# Epoch 30/60
# 41/41 - 74s - loss: 0.3494 - accuracy: 0.8497 - val_loss: 0.8030 - val_accuracy: 0.8995
# Epoch 31/60
# 41/41 - 74s - loss: 0.3503 - accuracy: 0.8494 - val_loss: 0.2296 - val_accuracy: 0.9184
# Epoch 32/60
# 41/41 - 74s - loss: 0.3501 - accuracy: 0.8490 - val_loss: 2.9438 - val_accuracy: 0.1350
# Epoch 33/60
# 41/41 - 73s - loss: 0.3512 - accuracy: 0.8488 - val_loss: 0.2310 - val_accuracy: 0.9180
# Epoch 34/60
# 41/41 - 74s - loss: 0.3495 - accuracy: 0.8502 - val_loss: 1.0496 - val_accuracy: 0.5087
# Epoch 35/60
# 41/41 - 76s - loss: 0.3517 - accuracy: 0.8486 - val_loss: 0.6607 - val_accuracy: 0.8997
# Epoch 36/60
# 41/41 - 81s - loss: 0.3492 - accuracy: 0.8496 - val_loss: 0.3412 - val_accuracy: 0.9052
# Epoch 37/60
# 41/41 - 82s - loss: 0.3514 - accuracy: 0.8489 - val_loss: 1.1657 - val_accuracy: 0.8995
# Epoch 38/60
# 41/41 - 75s - loss: 0.3543 - accuracy: 0.8466 - val_loss: 0.7083 - val_accuracy: 0.8996
# Epoch 39/60
# 41/41 - 74s - loss: 0.3540 - accuracy: 0.8472 - val_loss: 0.2826 - val_accuracy: 0.9101
# Epoch 40/60
# 41/41 - 77s - loss: 0.3512 - accuracy: 0.8491 - val_loss: 0.2303 - val_accuracy: 0.9116
# Epoch 41/60
# 41/41 - 77s - loss: 0.3540 - accuracy: 0.8474 - val_loss: 0.5275 - val_accuracy: 0.9005
# Epoch 42/60
# 41/41 - 79s - loss: 0.3522 - accuracy: 0.8479 - val_loss: 0.7732 - val_accuracy: 0.8995
# Epoch 43/60
# 41/41 - 79s - loss: 0.3504 - accuracy: 0.8488 - val_loss: 0.9764 - val_accuracy: 0.5403
# Epoch 44/60
# 41/41 - 81s - loss: 0.3489 - accuracy: 0.8501 - val_loss: 0.4569 - val_accuracy: 0.9018
# Epoch 45/60
# 41/41 - 79s - loss: 0.3496 - accuracy: 0.8498 - val_loss: 0.6359 - val_accuracy: 0.8998
# Epoch 46/60
# 41/41 - 83s - loss: 0.3524 - accuracy: 0.8481 - val_loss: 0.5768 - val_accuracy: 0.9000
# Epoch 47/60
# 41/41 - 76s - loss: 0.3503 - accuracy: 0.8497 - val_loss: 0.7936 - val_accuracy: 0.8995
# Epoch 48/60
# 41/41 - 83s - loss: 0.3502 - accuracy: 0.8496 - val_loss: 0.4338 - val_accuracy: 0.9032
# Epoch 49/60
# 41/41 - 85s - loss: 0.3499 - accuracy: 0.8501 - val_loss: 0.7089 - val_accuracy: 0.6621
# Epoch 50/60
# 41/41 - 78s - loss: 0.3485 - accuracy: 0.8498 - val_loss: 0.5096 - val_accuracy: 0.9003
# Epoch 51/60
# 41/41 - 77s - loss: 0.3436 - accuracy: 0.8526 - val_loss: 0.3467 - val_accuracy: 0.9044
# Epoch 52/60
# 41/41 - 75s - loss: 0.3432 - accuracy: 0.8531 - val_loss: 0.2661 - val_accuracy: 0.9106
# Epoch 53/60
# 41/41 - 78s - loss: 0.3429 - accuracy: 0.8532 - val_loss: 0.2702 - val_accuracy: 0.9100
# Epoch 54/60
# 41/41 - 76s - loss: 0.3430 - accuracy: 0.8532 - val_loss: 0.2209 - val_accuracy: 0.9182
# Epoch 55/60
# 41/41 - 77s - loss: 0.3428 - accuracy: 0.8531 - val_loss: 0.2109 - val_accuracy: 0.9211
# Epoch 56/60
# 41/41 - 78s - loss: 0.3430 - accuracy: 0.8534 - val_loss: 0.2123 - val_accuracy: 0.9203
# Epoch 57/60
# 41/41 - 73s - loss: 0.3426 - accuracy: 0.8532 - val_loss: 0.2122 - val_accuracy: 0.9204
# Epoch 58/60
# 41/41 - 75s - loss: 0.3427 - accuracy: 0.8531 - val_loss: 0.2297 - val_accuracy: 0.9163
# Epoch 59/60
# 41/41 - 77s - loss: 0.3426 - accuracy: 0.8531 - val_loss: 0.4686 - val_accuracy: 0.7841
# Epoch 60/60
# 41/41 - 79s - loss: 0.3427 - accuracy: 0.8535 - val_loss: 0.2348 - val_accuracy: 0.9107
# 0.8913421125690083
# Epoch 1/60
# 41/41 - 84s - loss: 0.4146 - accuracy: 0.8120 - val_loss: 1.6854 - val_accuracy: 0.8995
# Epoch 2/60
# 41/41 - 73s - loss: 0.3610 - accuracy: 0.8432 - val_loss: 1.5217 - val_accuracy: 0.8995
# Epoch 3/60
# 41/41 - 73s - loss: 0.3543 - accuracy: 0.8463 - val_loss: 1.6924 - val_accuracy: 0.8995
# Epoch 4/60
# 41/41 - 71s - loss: 0.3529 - accuracy: 0.8467 - val_loss: 1.7605 - val_accuracy: 0.8995
# Epoch 5/60
# 41/41 - 71s - loss: 0.3528 - accuracy: 0.8467 - val_loss: 1.5585 - val_accuracy: 0.8995
# Epoch 6/60
# 41/41 - 76s - loss: 0.3529 - accuracy: 0.8467 - val_loss: 1.3802 - val_accuracy: 0.8995
# Epoch 7/60
# 41/41 - 82s - loss: 0.3543 - accuracy: 0.8458 - val_loss: 1.5365 - val_accuracy: 0.8995
# Epoch 8/60
# 41/41 - 85s - loss: 0.3504 - accuracy: 0.8478 - val_loss: 1.1979 - val_accuracy: 0.8995
# Epoch 9/60
# 41/41 - 87s - loss: 0.3506 - accuracy: 0.8480 - val_loss: 1.3788 - val_accuracy: 0.8995
# Epoch 10/60
# 41/41 - 90s - loss: 0.3506 - accuracy: 0.8473 - val_loss: 1.2835 - val_accuracy: 0.8995
# Epoch 11/60
# 41/41 - 95s - loss: 0.3485 - accuracy: 0.8487 - val_loss: 0.6084 - val_accuracy: 0.8996
# Epoch 12/60
# 41/41 - 98s - loss: 0.3497 - accuracy: 0.8479 - val_loss: 1.1663 - val_accuracy: 0.8995
# Epoch 13/60
# 41/41 - 93s - loss: 0.3508 - accuracy: 0.8473 - val_loss: 0.8820 - val_accuracy: 0.8995
# Epoch 14/60
# 41/41 - 77s - loss: 0.3470 - accuracy: 0.8503 - val_loss: 0.7439 - val_accuracy: 0.8996
# Epoch 15/60
# 41/41 - 78s - loss: 0.3496 - accuracy: 0.8490 - val_loss: 1.5858 - val_accuracy: 0.8995
# Epoch 16/60
# 41/41 - 72s - loss: 0.3486 - accuracy: 0.8493 - val_loss: 0.4882 - val_accuracy: 0.9016
# Epoch 17/60
# 41/41 - 76s - loss: 0.3500 - accuracy: 0.8483 - val_loss: 1.2605 - val_accuracy: 0.8995
# Epoch 18/60
# 41/41 - 77s - loss: 0.3483 - accuracy: 0.8491 - val_loss: 1.0600 - val_accuracy: 0.8995
# Epoch 19/60
# 41/41 - 77s - loss: 0.3495 - accuracy: 0.8482 - val_loss: 1.0770 - val_accuracy: 0.8995
# Epoch 20/60
# 41/41 - 78s - loss: 0.3466 - accuracy: 0.8500 - val_loss: 0.5895 - val_accuracy: 0.9005
# Epoch 21/60
# 41/41 - 74s - loss: 0.3482 - accuracy: 0.8488 - val_loss: 0.2552 - val_accuracy: 0.9043
# Epoch 22/60
# 41/41 - 74s - loss: 0.3480 - accuracy: 0.8490 - val_loss: 1.1207 - val_accuracy: 0.5287
# Epoch 23/60
# 41/41 - 77s - loss: 0.3489 - accuracy: 0.8486 - val_loss: 0.3053 - val_accuracy: 0.9115
# Epoch 24/60
# 41/41 - 79s - loss: 0.3465 - accuracy: 0.8494 - val_loss: 1.1001 - val_accuracy: 0.8995
# Epoch 25/60
# 41/41 - 77s - loss: 0.3485 - accuracy: 0.8482 - val_loss: 1.1953 - val_accuracy: 0.8995
# Epoch 26/60
# 41/41 - 81s - loss: 0.3486 - accuracy: 0.8489 - val_loss: 0.5161 - val_accuracy: 0.9034
# Epoch 27/60
# 41/41 - 85s - loss: 0.3480 - accuracy: 0.8495 - val_loss: 0.4201 - val_accuracy: 0.9048
# Epoch 28/60
# 41/41 - 77s - loss: 0.3486 - accuracy: 0.8480 - val_loss: 0.7180 - val_accuracy: 0.8997
# Epoch 29/60
# 41/41 - 79s - loss: 0.3525 - accuracy: 0.8473 - val_loss: 4.4610 - val_accuracy: 0.1115
# Epoch 30/60
# 41/41 - 76s - loss: 0.3470 - accuracy: 0.8498 - val_loss: 0.3812 - val_accuracy: 0.9062
# Epoch 31/60
# 41/41 - 77s - loss: 0.3468 - accuracy: 0.8500 - val_loss: 0.8108 - val_accuracy: 0.8996
# Epoch 32/60
# 41/41 - 74s - loss: 0.3488 - accuracy: 0.8493 - val_loss: 1.0618 - val_accuracy: 0.8995
# Epoch 33/60
# 41/41 - 74s - loss: 0.3468 - accuracy: 0.8500 - val_loss: 0.7249 - val_accuracy: 0.8998
# Epoch 34/60
# 41/41 - 75s - loss: 0.3461 - accuracy: 0.8499 - val_loss: 0.2807 - val_accuracy: 0.9107
# Epoch 35/60
# 41/41 - 74s - loss: 0.3476 - accuracy: 0.8488 - val_loss: 0.9273 - val_accuracy: 0.8995
# Epoch 36/60
# 41/41 - 76s - loss: 0.3520 - accuracy: 0.8468 - val_loss: 0.5866 - val_accuracy: 0.9000
# Epoch 37/60
# 41/41 - 80s - loss: 0.3476 - accuracy: 0.8493 - val_loss: 0.2951 - val_accuracy: 0.9117
# Epoch 38/60
# 41/41 - 78s - loss: 0.3486 - accuracy: 0.8488 - val_loss: 0.3573 - val_accuracy: 0.9071
# Epoch 39/60
# 41/41 - 77s - loss: 0.3467 - accuracy: 0.8494 - val_loss: 0.2276 - val_accuracy: 0.9192
# Epoch 40/60
# 41/41 - 74s - loss: 0.3496 - accuracy: 0.8478 - val_loss: 0.5238 - val_accuracy: 0.9007
# Epoch 41/60
# 41/41 - 82s - loss: 0.3474 - accuracy: 0.8501 - val_loss: 0.7941 - val_accuracy: 0.8996
# Epoch 42/60
# 41/41 - 74s - loss: 0.3488 - accuracy: 0.8486 - val_loss: 0.4165 - val_accuracy: 0.9032
# Epoch 43/60
# 41/41 - 76s - loss: 0.3467 - accuracy: 0.8504 - val_loss: 1.3447 - val_accuracy: 0.4232
# Epoch 44/60
# 41/41 - 75s - loss: 0.3469 - accuracy: 0.8496 - val_loss: 0.2607 - val_accuracy: 0.8956
# Epoch 45/60
# 41/41 - 76s - loss: 0.3458 - accuracy: 0.8508 - val_loss: 0.2345 - val_accuracy: 0.9111
# Epoch 46/60
# 41/41 - 78s - loss: 0.3471 - accuracy: 0.8499 - val_loss: 0.5291 - val_accuracy: 0.9019
# Epoch 47/60
# 41/41 - 89s - loss: 0.3460 - accuracy: 0.8505 - val_loss: 0.2259 - val_accuracy: 0.9154
# Epoch 48/60
# 41/41 - 89s - loss: 0.3489 - accuracy: 0.8491 - val_loss: 0.3379 - val_accuracy: 0.9073
# Epoch 49/60
# 41/41 - 85s - loss: 0.3470 - accuracy: 0.8495 - val_loss: 0.2534 - val_accuracy: 0.9149
# Epoch 50/60
# 41/41 - 98s - loss: 0.3420 - accuracy: 0.8524 - val_loss: 0.2228 - val_accuracy: 0.9174
# Epoch 51/60
# 41/41 - 99s - loss: 0.3401 - accuracy: 0.8529 - val_loss: 0.2664 - val_accuracy: 0.8954
# Epoch 52/60
# 41/41 - 93s - loss: 0.3399 - accuracy: 0.8530 - val_loss: 0.3372 - val_accuracy: 0.8567
# Epoch 53/60
# 41/41 - 90s - loss: 0.3397 - accuracy: 0.8530 - val_loss: 0.2631 - val_accuracy: 0.8981
# Epoch 54/60
# 41/41 - 89s - loss: 0.3400 - accuracy: 0.8531 - val_loss: 0.2511 - val_accuracy: 0.9040
# Epoch 55/60
# 41/41 - 93s - loss: 0.3397 - accuracy: 0.8532 - val_loss: 0.2168 - val_accuracy: 0.9201
# Epoch 56/60
# 41/41 - 90s - loss: 0.3394 - accuracy: 0.8532 - val_loss: 0.2554 - val_accuracy: 0.9022
# Epoch 57/60
# 41/41 - 86s - loss: 0.3394 - accuracy: 0.8533 - val_loss: 0.3163 - val_accuracy: 0.8700
# Epoch 58/60
# 41/41 - 82s - loss: 0.3394 - accuracy: 0.8535 - val_loss: 0.2401 - val_accuracy: 0.9091
# Epoch 59/60
# 41/41 - 79s - loss: 0.3395 - accuracy: 0.8526 - val_loss: 0.2183 - val_accuracy: 0.9192
# Epoch 60/60
# 41/41 - 80s - loss: 0.3394 - accuracy: 0.8532 - val_loss: 0.2317 - val_accuracy: 0.9135
# 0.8855109028871352
# Epoch 1/60
# 41/41 - 79s - loss: 0.4202 - accuracy: 0.8087 - val_loss: 1.4706 - val_accuracy: 0.8995
# Epoch 2/60
# 41/41 - 77s - loss: 0.3630 - accuracy: 0.8421 - val_loss: 1.1917 - val_accuracy: 0.8995
# Epoch 3/60
# 41/41 - 78s - loss: 0.3589 - accuracy: 0.8439 - val_loss: 1.2758 - val_accuracy: 0.8995
# Epoch 4/60
# 41/41 - 78s - loss: 0.3571 - accuracy: 0.8457 - val_loss: 1.1419 - val_accuracy: 0.8995
# Epoch 5/60
# 41/41 - 71s - loss: 0.3542 - accuracy: 0.8472 - val_loss: 1.0918 - val_accuracy: 0.8995
# Epoch 6/60
# 41/41 - 76s - loss: 0.3551 - accuracy: 0.8466 - val_loss: 0.9632 - val_accuracy: 0.8995
# Epoch 7/60
# 41/41 - 74s - loss: 0.3538 - accuracy: 0.8473 - val_loss: 0.8147 - val_accuracy: 0.8995
# Epoch 8/60
# 41/41 - 68s - loss: 0.3540 - accuracy: 0.8461 - val_loss: 0.6957 - val_accuracy: 0.8996
# Epoch 9/60
# 41/41 - 73s - loss: 0.3527 - accuracy: 0.8472 - val_loss: 0.4504 - val_accuracy: 0.9007
# Epoch 10/60
# 41/41 - 69s - loss: 0.3528 - accuracy: 0.8476 - val_loss: 0.6069 - val_accuracy: 0.8999
# Epoch 11/60
# 41/41 - 69s - loss: 0.3528 - accuracy: 0.8471 - val_loss: 0.5591 - val_accuracy: 0.9001
# Epoch 12/60
# 41/41 - 69s - loss: 0.3530 - accuracy: 0.8473 - val_loss: 0.5418 - val_accuracy: 0.9001
# Epoch 13/60
# 41/41 - 69s - loss: 0.3516 - accuracy: 0.8484 - val_loss: 0.5648 - val_accuracy: 0.9001
# Epoch 14/60
# 41/41 - 70s - loss: 0.3538 - accuracy: 0.8468 - val_loss: 0.2987 - val_accuracy: 0.9106
# Epoch 15/60
# 41/41 - 70s - loss: 0.3528 - accuracy: 0.8478 - val_loss: 0.3721 - val_accuracy: 0.9049
# Epoch 16/60
# 41/41 - 70s - loss: 0.3525 - accuracy: 0.8482 - val_loss: 0.4164 - val_accuracy: 0.9022
# Epoch 17/60
# 41/41 - 69s - loss: 0.3524 - accuracy: 0.8483 - val_loss: 0.7308 - val_accuracy: 0.8997
# Epoch 18/60
# 41/41 - 69s - loss: 0.3499 - accuracy: 0.8492 - val_loss: 0.6959 - val_accuracy: 0.8996
# Epoch 19/60
# 41/41 - 68s - loss: 0.3511 - accuracy: 0.8485 - val_loss: 0.5461 - val_accuracy: 0.7471
# Epoch 20/60
# 41/41 - 68s - loss: 0.3517 - accuracy: 0.8478 - val_loss: 0.4990 - val_accuracy: 0.9009
# Epoch 21/60
# 41/41 - 68s - loss: 0.3528 - accuracy: 0.8476 - val_loss: 0.7823 - val_accuracy: 0.8996
# Epoch 22/60
# 41/41 - 68s - loss: 0.3502 - accuracy: 0.8489 - val_loss: 1.1808 - val_accuracy: 0.8995
# Epoch 23/60
# 41/41 - 68s - loss: 0.3524 - accuracy: 0.8480 - val_loss: 0.3124 - val_accuracy: 0.9090
# Epoch 24/60
# 41/41 - 68s - loss: 0.3564 - accuracy: 0.8459 - val_loss: 0.2193 - val_accuracy: 0.9170
# Epoch 25/60
# 41/41 - 68s - loss: 0.3504 - accuracy: 0.8490 - val_loss: 0.4854 - val_accuracy: 0.9013
# Epoch 26/60
# 41/41 - 68s - loss: 0.3505 - accuracy: 0.8488 - val_loss: 0.2234 - val_accuracy: 0.9186
# Epoch 27/60
# 41/41 - 68s - loss: 0.3527 - accuracy: 0.8472 - val_loss: 0.2628 - val_accuracy: 0.9122
# Epoch 28/60
# 41/41 - 68s - loss: 0.3512 - accuracy: 0.8484 - val_loss: 0.7109 - val_accuracy: 0.8997
# Epoch 29/60
# 41/41 - 68s - loss: 0.3508 - accuracy: 0.8483 - val_loss: 0.2972 - val_accuracy: 0.9089
# Epoch 30/60
# 41/41 - 68s - loss: 0.3492 - accuracy: 0.8497 - val_loss: 0.9031 - val_accuracy: 0.5564
# Epoch 31/60
# 41/41 - 68s - loss: 0.3526 - accuracy: 0.8473 - val_loss: 0.6864 - val_accuracy: 0.8997
# Epoch 32/60
# 41/41 - 68s - loss: 0.3500 - accuracy: 0.8484 - val_loss: 0.3089 - val_accuracy: 0.9084
# Epoch 33/60
# 41/41 - 68s - loss: 0.3493 - accuracy: 0.8492 - val_loss: 0.6913 - val_accuracy: 0.8997
# Epoch 34/60
# 41/41 - 68s - loss: 0.3495 - accuracy: 0.8488 - val_loss: 0.2861 - val_accuracy: 0.9106
# Epoch 35/60
# 41/41 - 69s - loss: 0.3534 - accuracy: 0.8468 - val_loss: 0.2986 - val_accuracy: 0.9081
# Epoch 36/60
# 41/41 - 68s - loss: 0.3510 - accuracy: 0.8482 - val_loss: 0.3980 - val_accuracy: 0.9030
# Epoch 37/60
# 41/41 - 68s - loss: 0.3516 - accuracy: 0.8484 - val_loss: 0.2218 - val_accuracy: 0.9163
# Epoch 38/60
# 41/41 - 68s - loss: 0.3493 - accuracy: 0.8493 - val_loss: 0.3818 - val_accuracy: 0.8311
# Epoch 39/60
# 41/41 - 68s - loss: 0.3490 - accuracy: 0.8499 - val_loss: 0.4398 - val_accuracy: 0.9013
# Epoch 40/60
# 41/41 - 68s - loss: 0.3496 - accuracy: 0.8489 - val_loss: 0.5599 - val_accuracy: 0.8999
# Epoch 41/60
# 41/41 - 68s - loss: 0.3504 - accuracy: 0.8481 - val_loss: 0.5132 - val_accuracy: 0.9004
# Epoch 42/60
# 41/41 - 68s - loss: 0.3486 - accuracy: 0.8495 - val_loss: 0.2271 - val_accuracy: 0.9171
# Epoch 43/60
# 41/41 - 68s - loss: 0.3515 - accuracy: 0.8480 - val_loss: 0.9712 - val_accuracy: 0.5249
# Epoch 44/60
# 41/41 - 68s - loss: 0.3513 - accuracy: 0.8478 - val_loss: 0.5135 - val_accuracy: 0.9007
# Epoch 45/60
# 41/41 - 68s - loss: 0.3512 - accuracy: 0.8481 - val_loss: 0.2696 - val_accuracy: 0.9116
# Epoch 46/60
# 41/41 - 68s - loss: 0.3499 - accuracy: 0.8495 - val_loss: 0.2361 - val_accuracy: 0.9085
# Epoch 47/60
# 41/41 - 68s - loss: 0.3496 - accuracy: 0.8484 - val_loss: 0.2674 - val_accuracy: 0.8938
# Epoch 48/60
# 41/41 - 68s - loss: 0.3497 - accuracy: 0.8490 - val_loss: 0.7141 - val_accuracy: 0.6548
# Epoch 49/60
# 41/41 - 68s - loss: 0.3497 - accuracy: 0.8495 - val_loss: 0.5578 - val_accuracy: 0.9002
# Epoch 50/60
# 41/41 - 69s - loss: 0.3442 - accuracy: 0.8517 - val_loss: 0.2135 - val_accuracy: 0.9197
# Epoch 51/60
# 41/41 - 68s - loss: 0.3422 - accuracy: 0.8529 - val_loss: 0.2121 - val_accuracy: 0.9201
# Epoch 52/60
# 41/41 - 68s - loss: 0.3419 - accuracy: 0.8532 - val_loss: 0.2107 - val_accuracy: 0.9205
# Epoch 53/60
# 41/41 - 68s - loss: 0.3417 - accuracy: 0.8533 - val_loss: 0.2105 - val_accuracy: 0.9207
# Epoch 54/60
# 41/41 - 68s - loss: 0.3415 - accuracy: 0.8532 - val_loss: 0.2602 - val_accuracy: 0.8992
# Epoch 55/60
# 41/41 - 68s - loss: 0.3415 - accuracy: 0.8530 - val_loss: 0.2175 - val_accuracy: 0.9181
# Epoch 56/60
# 41/41 - 69s - loss: 0.3413 - accuracy: 0.8532 - val_loss: 0.6434 - val_accuracy: 0.6799
# Epoch 57/60
# 41/41 - 68s - loss: 0.3414 - accuracy: 0.8534 - val_loss: 0.4224 - val_accuracy: 0.8095
# Epoch 58/60
# 41/41 - 68s - loss: 0.3415 - accuracy: 0.8532 - val_loss: 0.6516 - val_accuracy: 0.6746
# Epoch 59/60
# 41/41 - 68s - loss: 0.3412 - accuracy: 0.8534 - val_loss: 0.4059 - val_accuracy: 0.8192
# Epoch 60/60
# 41/41 - 68s - loss: 0.3415 - accuracy: 0.8532 - val_loss: 0.4293 - val_accuracy: 0.8060
# 0.8905509676338804

# %%
    yp = model.predict(test[features])
    val_score = roc_auc_score(y_valid, p_valid)
    val_aucs.append(val_score)

    print(roc_auc_score(y_valid, p_valid))
  
    predictions_nn1['fold{}'.format(fold+1)] = yp
# Out:
# 0.8905509676338804

# %%
print(get_model_3().summary())

# %%
# Submission
predictions_nn1['target'] = np.mean(predictions_nn1[[col for col in predictions_nn1.columns if col not in ['ID_code', 'target']]].values, axis=1)
sub = pd.DataFrame({"ID_code":test["ID_code"].values})
sub["target"] = predictions_nn1['target']
sub.to_csv("nn_submission_2.csv", index=False)
